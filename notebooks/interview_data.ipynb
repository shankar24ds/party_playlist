# %% [markdown]
# TODO
# 1. [x] check for exact duplicates. 444 entries.
# 2. [x] check if missing value can be filled. cant be filled.
# 3. [x] track_id uniqueness. df exploded using track_genre column.

# %%
# importing packages
import pandas as pd

# %%
# importing the spotify song info dataset
df = pd.read_csv('../data/raw/spotify.csv')

# %%
# viewing head and tail of the dataset
df
# Out:
#                       track_id                 artists  \
# 0       5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1       4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2       1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3       6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4       5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                        ...                     ...
# 113022  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113023  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113024  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113025  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113026  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# ...

# %%
# checking for null values and datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113027 entries, 0 to 113026
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          113027 non-null  object
#  1   artists           113026 non-null  object
#  2   album_name        113026 non-null  object
#  3   track_name        113026 non-null  object
#  4   popularity        113027 non-null  int64
#  5   duration_ms       113027 non-null  float64
#  6   explicit          113027 non-null  bool
#  7   danceability      113027 non-null  float64
#  8   energy            113027 non-null  float64
#  9   key               113027 non-null  int64
#  10  loudness          113027 non-null  float64
#  11  mode              113027 non-null  int64
#  12  speechiness       113027 non-null  float64
#  13  acousticness      113027 non-null  float64
#  14  instrumentalness  113027 non-null  float64
#  15  liveness          113027 non-null  float64
# ...

# %%
df.nunique()
# Out:
# track_id            88895
# artists             31267
# album_name          46325
# track_name          72935
# popularity            101
# duration_ms         50278
# explicit                2
# danceability         1169
# energy               2064
# key                    12
# loudness            19292
# mode                    2
# speechiness          1483
# acousticness         5053
# instrumentalness     5345
# liveness             1721
# valence              1779
# tempo               45242
# time_signature          4
# track_genre           114
# dtype: int64

# %%
df.describe()
# Out:
#           popularity   duration_ms   danceability         energy  \
# count  113027.000000  1.130270e+05  113027.000000  113027.000000
# mean       33.274386  2.281997e+05       0.568038       0.642947
# std        22.322053  1.070011e+05       0.172955       0.250418
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%        17.000000  1.743575e+05       0.457000       0.474000
# 50%        35.000000  2.130530e+05       0.581000       0.686000
# 75%        50.000000  2.615620e+05       0.695000       0.854000
# max       100.000000  5.237295e+06       0.985000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  113027.000000  113027.000000  113027.000000  113027.000000
# mean        5.312262      -8.219194       0.637299       0.084294
# std         3.560905       4.983277       0.480782       0.104315
# min         0.000000     -49.531000       0.000000       0.000000
# ...

# %%
# exact duplicate rows count
df.duplicated().sum()
# Out:
# 444

# %%
# checking if missing value can be filled
df[df['artists'].isnull()]
# Out:
#                      track_id artists album_name track_name  popularity  \
# 65326  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN           0
#
#        duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 65326          0.0     False         0.501   0.583    7     -9.46     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 65326       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature track_genre
# 65326  138.391               4       k-pop

# %%
df[df['track_id']=='1kR4gIb7nGxHPI3D2ifs59']
# Out:
#                      track_id artists album_name track_name  popularity  \
# 65326  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN           0
#
#        duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 65326          0.0     False         0.501   0.583    7     -9.46     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 65326       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature track_genre
# 65326  138.391               4       k-pop

# %% [raw]
# the above observation is valid

# %%
# track_id unique values investigation
filter_df = df['track_id'].value_counts().reset_index()
track_duplicates_list = list(filter_df[filter_df['count']>=2]['track_id'])
track_duplicates = df[df['track_id'].isin(track_duplicates_list)].sort_values('track_id')
track_duplicates
# Out:
#                       track_id            artists  \
# 14908   001APMDOl3qtx1526T11n1  Pink Sweat$;Kirby
# 102298  001APMDOl3qtx1526T11n1  Pink Sweat$;Kirby
# 2092    003vvx7Niy0yvhvHt4a68B        The Killers
# 3242    003vvx7Niy0yvhvHt4a68B        The Killers
# 91020   003vvx7Niy0yvhvHt4a68B        The Killers
# ...                        ...                ...
# 22088   7zv2vmZq8OjS54BxFzI2wM             Attila
# 72056   7zv2vmZq8OjS54BxFzI2wM             Attila
# 1990    7zwn1eykZtZ5LODrf7c0tS  The Neighbourhood
# 90620   7zwn1eykZtZ5LODrf7c0tS  The Neighbourhood
# 3085    7zwn1eykZtZ5LODrf7c0tS  The Neighbourhood
#
#                                              album_name            track_name  \
# 14908                                           New RnB                Better
# 102298                                          New RnB                Better
# 2092                                           Hot Fuss        Mr. Brightside
# ...

# %%
track_duplicates['track_id'].nunique()
# Out:
# 16541

# %% [raw]
# from the above, it is observed that spotify df is already exploded with track_genre column

# %%
# checking distribution of track_genre
df['track_genre'].value_counts()
# Out:
# track_genre
# rock             1000
# dance            1000
# salsa            1000
# house            1000
# chicago-house    1000
#                  ...
# grindcore         964
# ambient           961
# classical         958
# comedy            944
# sleep             943
# Name: count, Length: 114, dtype: int64

# %% [raw]
# It is likely the dataset is simulated from the above track_genre distribution, or sampled based on track_genre.
